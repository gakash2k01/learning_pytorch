# %%
def train_one_step(model, data_loader, optimizer):
  optimizer.zero_grad()
  for k,v in data.items():
    data[k] = v.to("cuda")
  loss = model(**data)
  # loss = model(x = data['x'], y = data['y'])
  loss.backward()
  optimizer.step()
  return loss

# %%
def train_one_epoch(model, data_loader, optimizer, scheduler):
  model.train()
  total_loss=0
  for batch_index, data in enumerate(data_loader):
    loss = train_one_step(model, data, optimizer)
    scheduler.step()
    total_loss = loss
  return total_loss

# %%
def validate_one_step(model, data_loader):
  for k,v in data.items():
    data[k] = v.to("cuda")
  loss = model(**data)
  return loss

# %%
def train_one_epoch(model, data_loader):
  model.train()
  total_loss=0
  for batch_index, data in enumerate(data_loader):
    with torch.no_grad():
      loss = train_one_step(model, data, optimizer)
    total_loss = loss
  return total_loss
